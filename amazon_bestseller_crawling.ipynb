# %%
# https://www.amazon.com/bestsellers
# 위 사이트에서 appliances카테고리의 모든 제품의 랭킹, 타이틀, 댓글수, 가격 정보를 출력하시오..
# 총 제품의 수는 100개..

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time

# %%
driver = webdriver.Chrome()

# %%
url = 'https://www.amazon.com/bestsellers'

# %%
driver.get(url)

# %%
driver.find_element_by_css_selector('#CardInstanceHCzYddMkAjCK7n72VdUdzg > div._p13n-zg-nav-tree-all_style_zg-browse-group__88fbz > div:nth-child(4) > a').click()
# Out:
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_9748/236746476.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_css_selector('#CardInstanceHCzYddMkAjCK7n72VdUdzg > div._p13n-zg-nav-tree-all_style_zg-browse-group__88fbz > div:nth-child(4) > a').click()

# %%
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

# %%
len(soup.select('li.zg-item-immersion'))
# Out:
# 50

# %%
lis = soup.select('li.zg-item-immersion')

# %%
lis[0].select('#zg-ordered-list > li > span > div > div > span.a-size-small.aok-float-left.zg-badge-body.zg-badge-color > span')[0].text
# Out:
# '#1'

# %%
lis[0].select('#zg-ordered-list > li > span > div > span > a > div')[0].text
# Out:
# 'Frigidaire EFIC-B-SS Ice Maker, Black Stainless Steel'

# %%
lis[2].select('#zg-ordered-list > li > span > div > span > div > a.a-size-small.a-link-normal')[0].text
# Out:
# '8,433'

# %%
lis[1].select('span.a-size-base.a-color-price')[0].text
# Out:
# '$316.98 - $317.00'

# %%
for li in lis:
    ranking = li.select('#zg-ordered-list > li > span > div > div > span.a-size-small.aok-float-left.zg-badge-body.zg-badge-color > span')[0].text
    title = li.select('#zg-ordered-list > li > span > div > span > a > div')[0].text
    comments_num = li.select('#zg-ordered-list > li > span > div > span > div > a.a-size-small.a-link-normal')[0].text
    price = li.select('span.a-size-base.a-color-price')[0].text
    
    print(ranking)
    print(title)
    print(comments_num)
    print(price)
    print('-----------')
# Out:
# #1
# Frigidaire EFIC-B-SS Ice Maker, Black Stainless Steel
# 452
# $89.98
# -----------
# #2
# Silonn Ice Makers Countertop, 9 Cubes Ready in 6 Mins, 26lbs in 24Hrs, Self-Cleaning Ice…
# 1,636
# $316.98 - $317.00
# -----------
# #3
# Frigidaire EFIC189-Silver Compact Ice Maker, 26 lb per Day, Silver
# 8,433
# $129.99
# -----------
# #4
# AGLUCKY Ice Maker Machine for Countertop, Portable Ice Cube Makers, Make 26 lbs ice in…
# 10,738
# $110.49
# -----------
# #5
# GE Profile Opal | Countertop Nugget Ice Maker with Side Tank | Portable Ice Machine with…
# 15,109
# $412.49
# -----------
# #6
# 2-Pack Ice Machine Cleaner and Descaler 16 fl oz, Nickel Safe Descaler | Ice Maker Cleaner…
# 774
# $19.99 - $44.99
# -----------
# #7
# OxiClean Gel Sticks - 6.2 oz - 2 pk by OxiClean
# 289
# $15.69
# -----------
# #8
# Midea MRU03M2ABB Upright Freezer Large Black, 3.0 Cubic Feet
# 12,134
# $157.55 - $420.00
# -----------
# #9
# Arctic King 5 cu ft Chest Freezer for Your House, Garage, Basement, Apartment,…
# 6,933
# $199.00
# -----------
# #10
# Arctic King Chest Freezer 5 cu ft (Black)
# 229
# $207.88
# -----------
# #11
# Giantex Portable Mini Compact Twin Tub Washing Machine 17.6lbs Washer Spain…
# 10,870
# $199.99
# -----------
# #12
# Broan-NuTone 412101 Non-Ducted Ductless Range Hood with Lights Exhaust Fan for…
# 12,050
# $42.84 - $312.34
# -----------
# #13
# Euhomy Ice Maker Machine Countertop,26 lbs in 24 Hours,9 Cubes Ready in 6 Mins, Electric…
# 8,979
# $129.99
# -----------
# #14
# Midea MRU03M2ABB Upright Freezer Large Black, 3.0 Cubic Feet
# 12,134
# $183.08
# -----------
# #15
# SUPER DEAL Compact Mini Twin Tub Washing Machine, Portable Laundry Washer w/Wash…
# 7,877
# $163.99
# -----------
# #16
# COMFEE’ 1.6 Cu.ft Portable Washing Machine, 11lbs Capacity Fully Automatic Compact…
# 2,779
# $323.51 - $658.00
# -----------
# #17
# Broan-NuTone F403008 Two-Speed Four-Way Convertible Range Hood, 30-Inch, Almond
# 6,548
# $51.80 - $305.24
# -----------
# #18
# Broan-NuTone 30-inch Under-Cabinet Convertible Range Hood with 2-Speed…
# 1,478
# $49.98 - $134.66
# -----------
# #19
# COSTWAY Mini Washing Machine with Spin Dryer, Washing Capacity 5.5lbs, Electric…
# 3,668
# $102.99
# -----------
# #20
# Broan-NuTone SP3004 Reversible Stainless Steel Backsplash Range Hood Wall Shield for…
# 2,239
# $67.49
# -----------
# #21
# Frigidaire EFIC121-SSBLACK Ice Maker, Black Stainless
# 853
# $140.00 - $299.99
# -----------
# #22
# Dreamiracle Ice Maker Machine Countertop, 26 lbs in 24 Hours, Self-cleaning Ice Maker…
# 188
# $129.99
# -----------
# #23
# Wizisa Ice Maker Machine for Countertop, 9 Bullet Ice Cubes Ready in 6 Minutes, 26lbs in…
# 390
# $112.99
# -----------
# #24
# Oline Ice Maker Machine, Automatic Self-Cleaning Portable Electric Countertop Ice…
# 730
# $99.95 - $109.95
# -----------
# #25
# Portable Washing Machine Mini Washing 3in1 Dishwashers Mini Lights Ultrasonic Waves…
# 98
# $22.99 - $25.99
# -----------
# #26
# Frigidaire EFR341, 3.2 cu ft 2 Door Fridge and Freezer, Platinum Series, Stainless Steel,…
# 938
# $329.82 - $699.99
# -----------
# #27
# VIVOHOME Electric Portable Compact Countertop Automatic Ice Cube Maker…
# 4,921
# $119.33
# -----------
# #28
# Whynter CUF-110B Energy Star 1.1 Cubic Feet Upright Lock, Black Freezer
# 4,819
# $177.51 - $1,000.00
# -----------
# #29
# COMFEE' Portable Washing Machine, 0.9 cu.ft Compact Washer With LED Display, 5 Wash…
# 1,989
# $249.00 - $429.99
# -----------
# #30
# Arctic King 7 cu ft Chest Freezer, Black
# 348
# $243.98
# -----------
# #31
# EdgeStar DWP62SV 6 Place Setting Energy Star Rated Portable Countertop Dishwasher - Silver
# 717
# $299.00
# -----------
# #32
# Frigidaire EFIC237 Countertop Crunchy Chewable Nugget Ice Maker, 44lbs per Day,…
# 46
# $255.53
# -----------
# #33
# Frigidaire EFIC452-SSBLACK XL Maker, Makes 40 Lbs. of Clear Square Ice Cubes A Day,…
# 1,913
# $193.89 - $274.27
# -----------
# #34
# Cosmo COS-5MU30 30 in. Under Cabinet Range Hood Ductless Convertible Duct, Slim…
# 5,003
# $129.95 - $273.82
# -----------
# #35
# COSTWAY Compact Laundry Dryer, 110V Electric Portable Clothes Dryer with Stainless…
# 1,814
# $279.99
# -----------
# #36
# BLACK & DECKER BPWM09W Portable Washer
# 1,461
# $253.33
# -----------
# #37
# Igloo ICEB26AQ Automatic Portable Electric Countertop Ice Maker Machine, 26 Pounds in…
# 7,661
# $149.99 - $285.00
# -----------
# #38
# Cosmo 63175S 30 in. Wall Mount Range Hood with Ductless Convertible Duct (additional…
# 1,104
# $249.99
# -----------
# #39
# KOBE Range Hoods INX2930SQBF-500-1 Built-In/Insert Range Hood, 30"
# 429
# $287.79 - $946.00
# -----------
# #40
# Frigidaire Counter Top Ice Maker, Produces 26 pounds Ice per Day, Stainless Steel with…
# 282
# $91.08
# -----------
# #41
# BANGSON Portable Washing Machine, 17.6 lbs Washer(11Lbs) and Spinner(6.6Lbs), Mini…
# 364
# $139.99 - $172.98
# -----------
# #42
# Refrigerator Garage Heater Kit for Frigidaire Kenmore Refrigerator 5303918301…
# 575
# $15.99
# -----------
# #43
# Cosmo 668ICS750 30 in. Island Mount Range Hood with 380 CFM, Soft Touch Controls,…
# 1,478
# $382.21 - $615.38
# -----------
# #44
# Countertop Ice Maker Machine Portable, Self Cleaning Function, Mini Ice Makers, Make 26…
# 2,068
# $99.99
# -----------
# #45
# Deco Rapid Portable Automatic Electric Countertop Ice Maker - 6 Great Colors…
# 1,454
# $109.99 - $129.99
# -----------
# #46
# CROWNFUL Ice Maker Countertop Machine, 9 Ice Cubes Ready in 8 Minutes, 26lbs Bullet Ice…
# 3,963
# $89.99
# -----------
# #47
# The Laundry Alternative, WonderWash, Portable Washing Machine, Mini Washer,…
# 4,214
# $69.95 - $109.97
# -----------
# #48
# HCK44 Power Cord Kit, Compatible with Broan, Also Compatible with Whirlpool W10831110,…
# 78
# $12.91
# -----------
# #49
# Upstreman 3.2 Cu.Ft Mini Fridge with Freezer,2 door, Adjustable Thermostat, Low noise,…
# 3
# $249.97
# -----------
# #50
# GLACIALPURE Ice2 F2wc9i1 Cap Ice Maker Water Filter Compatible with W10565350,…
# 24
# $36.99 - $45.99
# -----------

# %%
driver = webdriver.Chrome()

# %%
url = 'https://www.amazon.com/bestsellers'

# %%
driver.get(url)

# %%
url = 'https://www.amazon.com/Best-Sellers-Appliances/zgbs/appliances/ref=zg_bs_pg_1?_encoding=UTF8&pg={}'

for i in range(1,3):
    
    url = url.format(i)
    print(url)
    driver.get(url)
    
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    
    lis = soup.select('li.zg-item-immersion')
    
    for li in lis:
        ranking = li.select('#zg-ordered-list > li > span > div > div > span.a-size-small.aok-float-left.zg-badge-body.zg-badge-color > span')[0].text
        title = li.select('#zg-ordered-list > li > span > div > span > a > div')[0].text
        comments_num = li.select('#zg-ordered-list > li > span > div > span > div > a.a-size-small.a-link-normal')[0].text
        price = li.select('span.a-size-base.a-color-price')[0].text

        print(ranking)
        print(title)
        print(comments_num)
        print(price)
        print('-----------')
# Out:
# https://www.amazon.com/Best-Sellers-Appliances/zgbs/appliances/ref=zg_bs_pg_1?_encoding=UTF8&pg=1
# https://www.amazon.com/Best-Sellers-Appliances/zgbs/appliances/ref=zg_bs_pg_1?_encoding=UTF8&pg=1

# %%
url = 'https://www.amazon.com/bestsellers'

driver = webdriver.Chrome()
driver.get(url)

driver.find_element_by_link_text('Appliances').click()
# Out:
# C:\Users\bitcamp\AppData\Local\Temp/ipykernel_9748/4244660820.py:6: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_link_text('Appliances').click()

# %%
# url = 'https://www.amazon.com/Best-Sellers-Appliances/zgbs/appliances/ref=zg_bs_pg_1?_encoding=UTF8&pg={}'
# url = 'https://www.amazon.com/Best-Sellers-Appliances/zgbs/appliances/ref=zg_bs_nav_0'

for i in range(1,3):
    
    if i == 2:
        url = 'https://www.amazon.com/Best-Sellers-Appliances/zgbs/appliances/ref=zg_bs_pg_{}?_encoding=UTF8&pg=2'
        url = url.format(2)
        
        driver.get(url)

    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    
    lis = soup.select('li.zg-item-immersion')
#     print(lis)
    
    for li in lis:
        
        try:
            ranking = li.select('#zg-ordered-list > li > span > div > div > span.a-size-small.aok-float-left.zg-badge-body.zg-badge-color > span')[0].text
            title = li.select('#zg-ordered-list > li > span > div > span > a > div')[0].text
            comments_num = li.select('#zg-ordered-list > li > span > div > span > div > a.a-size-small.a-link-normal')[0].text
            price = li.select('span.a-size-base.a-color-price')[0].text

            print(ranking)
            print(title)
            print(comments_num)
            print(price)
            print('-----------')
        except:
            pass
        
#     print(i)
# Out:
# #1
# Frigidaire EFIC-B-SS Ice Maker, Black Stainless Steel
# 452
# $89.98
# -----------
# #2
# Silonn Ice Makers Countertop, 9 Cubes Ready in 6 Mins, 26lbs in 24Hrs, Self-Cleaning Ice…
# 1,635
# $316.98 - $317.00
# -----------
# #3
# Frigidaire EFIC189-Silver Compact Ice Maker, 26 lb per Day, Silver
# 8,433
# $129.99
# -----------
# #4
# AGLUCKY Ice Maker Machine for Countertop, Portable Ice Cube Makers, Make 26 lbs ice in…
# 10,739
# $110.49
# -----------
# #5
# GE Profile Opal | Countertop Nugget Ice Maker with Side Tank | Portable Ice Machine with…
# 15,109
# $412.49
# -----------
# #6
# 2-Pack Ice Machine Cleaner and Descaler 16 fl oz, Nickel Safe Descaler | Ice Maker Cleaner…
# 775
# $19.99 - $44.99
# -----------
# #7
# OxiClean Gel Sticks - 6.2 oz - 2 pk by OxiClean
# 289
# $15.69
# -----------
# #8
# Midea MRU03M2ABB Upright Freezer Large Black, 3.0 Cubic Feet
# 12,134
# $157.55 - $420.00
# -----------
# #9
# Arctic King 5 cu ft Chest Freezer for Your House, Garage, Basement, Apartment,…
# 6,933
# $199.00
# -----------
# #10
# Arctic King Chest Freezer 5 cu ft (Black)
# 229
# $207.88
# -----------
# #11
# Giantex Portable Mini Compact Twin Tub Washing Machine 17.6lbs Washer Spain…
# 10,870
# $199.99
# -----------
# #12
# Broan-NuTone 412101 Non-Ducted Ductless Range Hood with Lights Exhaust Fan for…
# 12,050
# $42.84 - $312.33
# -----------
# #13
# Euhomy Ice Maker Machine Countertop,26 lbs in 24 Hours,9 Cubes Ready in 6 Mins, Electric…
# 8,979
# $129.99
# -----------
# #14
# Dreamiracle Ice Maker Machine Countertop, 26 lbs in 24 Hours, Self-cleaning Ice Maker…
# 188
# $129.99
# -----------
# #15
# Midea MRU03M2ABB Upright Freezer Large Black, 3.0 Cubic Feet
# 12,134
# $183.08
# -----------
# #16
# SUPER DEAL Compact Mini Twin Tub Washing Machine, Portable Laundry Washer w/Wash…
# 7,877
# $163.99
# -----------
# #17
# COMFEE’ 1.6 Cu.ft Portable Washing Machine, 11lbs Capacity Fully Automatic Compact…
# 2,779
# $323.51 - $658.00
# -----------
# #18
# Broan-NuTone F403008 Two-Speed Four-Way Convertible Range Hood, 30-Inch, Almond
# 6,548
# $51.80 - $305.24
# -----------
# #19
# Broan-NuTone 30-inch Under-Cabinet Convertible Range Hood with 2-Speed…
# 1,478
# $49.98 - $134.66
# -----------
# #20
# Portable Washing Machine Mini Washing 3in1 Dishwashers Mini Lights Ultrasonic Waves…
# 98
# $22.99 - $25.99
# -----------
# #21
# Frigidaire EFIC452-SSBLACK XL Maker, Makes 40 Lbs. of Clear Square Ice Cubes A Day,…
# 1,913
# $193.89 - $274.27
# -----------
# #22
# Whynter CUF-110B Energy Star 1.1 Cubic Feet Upright Lock, Black Freezer
# 4,819
# $177.51 - $1,000.00
# -----------
# #23
# Frigidaire EFIC121-SSBLACK Ice Maker, Black Stainless
# 854
# $140.00 - $299.99
# -----------
# #24
# Frigidaire EFIC237 Countertop Crunchy Chewable Nugget Ice Maker, 44lbs per Day,…
# 46
# $255.53
# -----------
# #25
# EdgeStar DWP62SV 6 Place Setting Energy Star Rated Portable Countertop Dishwasher - Silver
# 717
# $299.00
# -----------
# #26
# Broan-NuTone SP3004 Reversible Stainless Steel Backsplash Range Hood Wall Shield for…
# 2,239
# $67.49
# -----------
# #27
# Arctic King 7 cu ft Chest Freezer, Black
# 348
# $243.98
# -----------
# #28
# Frigidaire EFR341, 3.2 cu ft 2 Door Fridge and Freezer, Platinum Series, Stainless Steel,…
# 938
# $329.82 - $699.99
# -----------
# #29
# Oline Ice Maker Machine, Automatic Self-Cleaning Portable Electric Countertop Ice…
# 730
# $99.95 - $109.95
# -----------
# #30
# COSTWAY Mini Washing Machine with Spin Dryer, Washing Capacity 5.5lbs, Electric…
# 3,668
# $102.99
# -----------
# #31
# VIVOHOME Electric Portable Compact Countertop Automatic Ice Cube Maker…
# 4,922
# $119.33
# -----------
# #32
# COMFEE' Portable Washing Machine, 0.9 cu.ft Compact Washer With LED Display, 5 Wash…
# 1,989
# $249.00 - $429.99
# -----------
# #33
# Wizisa Ice Maker Machine for Countertop, 9 Bullet Ice Cubes Ready in 6 Minutes, 26lbs in…
# 390
# $112.99
# -----------
# #34
# Cosmo COS-5MU30 30 in. Under Cabinet Range Hood Ductless Convertible Duct, Slim…
# 5,003
# $129.95 - $273.82
# -----------
# #35
# COSTWAY Compact Laundry Dryer, 110V Electric Portable Clothes Dryer with Stainless…
# 1,814
# $279.99
# -----------
# #36
# BANGSON Portable Washing Machine, 17.6 lbs Washer(11Lbs) and Spinner(6.6Lbs), Mini…
# 364
# $139.99 - $172.98
# -----------
# #37
# Igloo ICEB26AQ Automatic Portable Electric Countertop Ice Maker Machine, 26 Pounds in…
# 7,661
# $149.99 - $285.00
# -----------
# #38
# CROWNFUL Ice Maker Countertop Machine, 9 Ice Cubes Ready in 8 Minutes, 26lbs Bullet Ice…
# 3,963
# $89.99
# -----------
# #39
# BLACK & DECKER BPWM09W Portable Washer
# 1,461
# $253.33
# -----------
# #40
# Frigidaire Counter Top Ice Maker, Produces 26 pounds Ice per Day, Stainless Steel with…
# 282
# $91.08
# -----------
# #41
# KOBE Range Hoods INX2930SQBF-500-1 Built-In/Insert Range Hood, 30"
# 429
# $287.79 - $946.00
# -----------
# #42
# Deco Rapid Portable Automatic Electric Countertop Ice Maker - 6 Great Colors…
# 1,454
# $109.99 - $129.99
# -----------
# #43
# AIRMSEN AE-TDQR03 Portable Countertop Dishwasher, Compact Mini Dishwasher with 5…
# 103
# $359.99
# -----------
# #44
# Cosmo 668ICS750 30 in. Island Mount Range Hood with 380 CFM, Soft Touch Controls,…
# 1,478
# $382.21 - $615.38
# -----------
# #45
# Cosmo 63175S 30 in. Wall Mount Range Hood with Ductless Convertible Duct (additional…
# 1,104
# $249.99
# -----------
# #46
# Upstreman 3.2 Cu.Ft Mini Fridge with Freezer,2 door, Adjustable Thermostat, Low noise,…
# 3
# $249.97
# -----------
# #47
# HCK44 Power Cord Kit, Compatible with Broan, Also Compatible with Whirlpool W10831110,…
# 78
# $12.91
# -----------
# #48
# Refrigerator Garage Heater Kit for Frigidaire Kenmore Refrigerator 5303918301…
# 575
# $15.99
# -----------
# #49
# Countertop Ice Maker Machine Portable, Self Cleaning Function, Mini Ice Makers, Make 26…
# 2,068
# $99.99
# -----------
# #50
# The Laundry Alternative, WonderWash, Portable Washing Machine, Mini Washer,…
# 4,214
# $69.95 - $109.97
# -----------
# #52
# 5cf Chest Freezer Deep 5 Cu Ft Compact Dorm Upright Apartment Home Food Storage…
# 2,522
# $208.50
# -----------
# #53
# Igloo Automatic Portable Electric Countertop Ice Maker Machine, 26 Pounds in 24 Hours, 9…
# 2,398
# $134.99 - $262.36
# -----------
# #54
# Kismile Counter top Ice Maker Machine with Self-Cleaning, 26LBS/24H Compact…
# 3,449
# $129.99 - $144.99
# -----------
# #55
# Frigidaire EFRF696-AMZ Upright Freezer 6.5 cu ft Stainless Platinum Design Series
# 822
# $199.77
# -----------
# #56
# Broan-NuTone 403023 B000UW02A6 ADA Capable Under-Cabinet Range Hood, 30 Inch,…
# 1,166
# $53.00
# -----------
# #57
# Ice Maker Portable Ice Maker Countertop Ice Maker Machine for Home/Office/Camping…
# 445
# $118.77
# -----------
# #58
# Cosmo 5U30 30 in. Under Cabinet Range Hood with Ducted / Ductless Convertible Slim…
# 1,816
# $138.99
# -----------
# #59
# Euhomy Ice Maker Machine Countertop, 40Lbs/24H Auto Self-Cleaning, 24 pcs Ice…
# 4,107
# $199.99 - $249.99
# -----------
# #60
# Frigidaire FFEC3025US 30 Inch Electric Smoothtop Style Cooktop with 4 Elements,…
# 35
# $429.00
# -----------
# #61
# Broan-NuTone LB30 Box Hood Liner for Kitchen Range Hoods, Silver, 30"
# 529
# $51.99
# -----------
# #62
# FRIGIDAIRE EFIC235-AMZ Countertop Crunchy Chewable Nugget Ice Maker, 44lbs per Day,…
# 1,710
# $233.43
# -----------
# #63
# Broan-NuTone S97016565 Heating Element for Heater
# 772
# $35.10
# -----------
# #64
# Mini Washing Machine Ultrasonic Turbine Washing Machine Portable Turbo Washer for…
# 93
# $23.66
# -----------
# #65
# CROWNFUL Ice Maker Machine for Countertop, 9 Bullet Ice Cubes S/L Ready in 7 Minutes,…
# 7,418
# $85.99
# -----------
# #66
# Dreamiracle Ice Maker Machine for Countertop, 33 lbs Bullet Ice Cube in 24H, 9 Ice Cubes…
# 1,420
# $219.99
# -----------
# #67
# Kenmore Top-Freezer Refrigerator with LED Lighting and 20.8 Cubic Ft. Total Capacity,…
# 259
# $659.12
# -----------
# #68
# Broan-NuTone Broan Light Lens, White
# 1,475
# $12.95
# -----------
# #69
# Winia WTE18HSBMD 18 Cu. Ft. Top Mount Refrigerator With Factory Installed Ice Maker…
# 2
# $534.13
# -----------
# #70
# IKTCH 30 inch Built-in/Insert Range Hood with 900 CFM, Ducted/Ductless Convertible Duct,…
# 365
# $299.00 - $345.00
# -----------
# #71
# Hauslane | Chef Series 30" PS18 Under Cabinet Range Hood, Matte Black | Pro Performance |…
# 1,607
# $399.99
# -----------
# #72
# BROAN NuTone BCSQ130SS Three-Speed Glacier Under-Cabinet Range Hood with LED…
# 312
# $168.00 - $415.99
# -----------
# #73
# TRUSTECH Ice Maker Machine for Countertop, Self-Cleaning Function, 26Lbs/24H Portable…
# 2,207
# $93.59
# -----------
# #74
# Euhomy Mini Freezer Countertop, 1.1 Cubic Feet, Single Door Compact Upright Freezer…
# 3,414
# $169.99 - $259.99
# -----------
# #75
# Ice Maker Countertop Machine, 9 Bullet Ice Cubes Ready in 6 Mins, 22lbs Ice Cubes in…
# 82
# $120.99
# -----------
# #76
# Galanz GLR74BRDR12 Retro Bottom Mount Refrigerator, Adjustable Mechanical…
# 1,171
# $654.00 - $1,698.88
# -----------
# #77
# XtremepowerUS Deluxe Propane Gas Range Stove 2 Burner Stainless Steel Cooktop Auto…
# 426
# $89.95 - $94.95
# -----------
# #78
# Frigidaire FGIC3066TB Gallery 30" Electric Induction Cooktop, Built-in 4-Burner,…
# 500
# $889.00 - $1,949.00
# -----------
# #79
# Broan-NuTone BUEZ230SS Broan Economy UC 190 CFM 30N Stainless Under Cabinet Range…
# 1,348
# $50.21 - $199.00
# -----------
# #80
# The Laundry Alternative - Ninja Portable Mini 3200 RPM Centrifugal Spin Clothes Dryer…
# 612
# $158.00
# -----------
# #81
# Garatic Portable Compact Mini Twin Tub Washing Machine w/Wash and Spin Cycle,…
# 2,677
# $159.99
# -----------
# #82
# Shark Industrial 25 FT Stainless Steel Braided Ice Maker Hose with 1/4" Comp by 1/4"…
# 549
# $22.95
# -----------
# #83
# Broan-NuTone 413623 Broan 41000, 36-Inch, Black
# 1,565
# $65.00 - $205.29
# -----------
# #84
# Portable Mini Washing Machine,Ultrasonic Turbo Washing Machine 3 In 1,Portable…
# 4
# $20.98
# -----------
# #85
# Electric Cooktop, thermomate 24 Inch Built-in Radiant Electric Stove Top, 240V Ceramic…
# 430
# $249.99 - $499.99
# -----------
# #86
# ZenStyle Portable Washer Compact Twin Tub 9.9 LB Mini Top Load Washing Machine…
# 647
# $115.99
# -----------
# #87
# Gas Stove Gas Cooktop 2 Burners,12 Inches Portable Stainless Steel Built-in Gas Hob LPG…
# 401
# $119.99
# -----------
# #88
# Clothes Dryer Portable Travel Mini 900W dryer machine,Portable dryer for apartments,New…
# 394
# $59.99
# -----------
# #89
# I'SMARTMOON Mini-Fridge-Stand 4 Strong Feet，Adjustable Dolly Washing Machine…
# 137
# $26.79
# -----------
# #90
# Cosmo COS-668AS750 30 in. Wall Mount Range Hood with 380 CFM, Curved Glass,…
# 586
# $256.53
# -----------
# #91
# Broan-NuTone BCSD130BL Glacier Range Hood with Light, Exhaust Fan for Under Cabinet,…
# 243
# $129.92
# -----------
# #92
# Ultra Durable 5303918301 Refrigerator Garage Heater Kit - Refrigerator Garage Heater Kit…
# 181
# $14.27
# -----------
# #93
# Range Hood Insert 30 Inch,Vent Hood Insert,Ducted/Ductless Convertible Range…
# 126
# $319.99 - $369.99
# -----------
# #94
# SUPER DEAL Portable Compact Washing Machine 9.9 LB Mini Twin Tub Top Load…
# 3,898
# $114.59
# -----------
# #95
# East doll Portable Washing Machine for Baby Clothes, Underwear or Small Items, Foldable…
# 336
# $80.99
# -----------
# #96
# Prime Home Direct Ice Makers Countertop - Ice Maker Machine for Counter top Makes Ice…
# 1,978
# $154.88
# -----------
# #97
# EasyGoProducts Washing Wand Hand Powered For Camping Apts and More, Portable…
# 1,733
# $19.79
# -----------
# #98
# BROAN NuTone BWP2244SS Convertible Wall-Mount LED Lights Pyramidal Chimney Range…
# 199
# $340.00 - $809.95
# -----------
# #99
# ZENY Portable Mini Laundry Washing Machine Small Semi-Automatic Compact Washer Spin…
# 662
# $87.99
# -----------
# #100
# Fluidmaster 12IM72 Braided Stainless Steel Ice Maker Connector Water Line with Dual 1/4…
# 1,380
# $17.54 - $31.79
# -----------
